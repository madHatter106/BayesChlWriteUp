# %% [markdown]
# ## <u>Notebook Synopsis</u>
# In the previous notebook, I cleaned a subset of data, stored in a pandas dataframe, from the _NOMAD_ 2008 dataset, which I then pickled as "*df_main.pkl*". I also put the _NOMAD_ data in a dataframe and pickled it as "*df_raw.pkl*". All pickled files are contained in the subfolder "pickleJar" of this project folder. In this notebook I create several smaller datasets, one for the present study (*df_clean_nopurple_nored*), and others for later use in follow-up projects.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_pickle("./pickleJar/df_main.pkl")

# %%
df.describe()
# Out:
#                 id       rrs411       rrs443       rrs489       rrs510  \
# count  4459.000000  4293.000000  4456.000000  4422.000000  3435.000000
# mean   4377.381251     0.004881     0.004652     0.004590     0.004130
# std    2298.272102     0.003447     0.003002     0.002768     0.003130
# min       6.000000     0.000051     0.000190     0.000284     0.000261
# 25%    2028.500000     0.002509     0.002617     0.003051     0.002831
# 50%    5039.000000     0.003984     0.003899     0.004153     0.003425
# 75%    6271.500000     0.006301     0.006076     0.005655     0.004242
# max    7831.000000     0.030600     0.036769     0.063814     0.077740
#
#             rrs555       rrs670      chlor_a
# count  3255.000000  1598.000000  4127.000000
# mean      0.003256     0.001557     2.680228
# std       0.003536     0.002387     5.758436
# min       0.000183     0.000000     0.012000
# 25%       0.001588     0.000200     0.233325
# 50%       0.002071     0.000614     0.764000
# 75%       0.003141     0.002000     2.150000
# max       0.046600     0.027700    77.864800

# %% [markdown]
# In the table above the "min" row shows there are null (=0) entries in the rrs670 column, which need to be marked as invalid (NaN)

# %%
df.replace(0, np.NaN, inplace=True)

# %%
df.describe()
# Out:
#                 id       rrs411       rrs443       rrs489       rrs510  \
# count  4459.000000  4293.000000  4456.000000  4422.000000  3435.000000
# mean   4377.381251     0.004881     0.004652     0.004590     0.004130
# std    2298.272102     0.003447     0.003002     0.002768     0.003130
# min       6.000000     0.000051     0.000190     0.000284     0.000261
# 25%    2028.500000     0.002509     0.002617     0.003051     0.002831
# 50%    5039.000000     0.003984     0.003899     0.004153     0.003425
# 75%    6271.500000     0.006301     0.006076     0.005655     0.004242
# max    7831.000000     0.030600     0.036769     0.063814     0.077740
#
#             rrs555       rrs670      chlor_a
# count  3255.000000  1515.000000  4127.000000
# mean      0.003256     0.001642     2.680228
# std       0.003536     0.002422     5.758436
# min       0.000183     0.000030     0.012000
# 25%       0.001588     0.000222     0.233325
# 50%       0.002071     0.000700     0.764000
# 75%       0.003141     0.002111     2.150000
# max       0.046600     0.027700    77.864800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 9 columns):
# id         4459 non-null int64
# rrs411     4293 non-null float64
# rrs443     4456 non-null float64
# rrs489     4422 non-null float64
# rrs510     3435 non-null float64
# rrs555     3255 non-null float64
# rrs670     1515 non-null float64
# chlor_a    4127 non-null float64
# is_hplc    4459 non-null bool
# dtypes: bool(1), float64(7), int64(1)
# memory usage: 283.1 KB

# %%
rrs_cols = df.filter(regex='rrs', axis=1).columns.tolist()

# %% [markdown]
# ## Subsetting:
# Here I turn out smaller datasets for later use in this and other projects.
#
# ### $\Rightarrow$ Subset all columns leaving out rrs670
# Note that here I leave NaNs in the dataset, for possible imputation in a later project.

# %%
rrs_cols_nored = rrs_cols[:-1]

# %%
df_no_red = df.loc[:, ['id'] + rrs_cols_nored + ['chlor_a', 'is_hplc']]

# %%
df_no_red.describe()
# Out:
#                 id       rrs411       rrs443       rrs489       rrs510  \
# count  4459.000000  4293.000000  4456.000000  4422.000000  3435.000000
# mean   4377.381251     0.004881     0.004652     0.004590     0.004130
# std    2298.272102     0.003447     0.003002     0.002768     0.003130
# min       6.000000     0.000051     0.000190     0.000284     0.000261
# 25%    2028.500000     0.002509     0.002617     0.003051     0.002831
# 50%    5039.000000     0.003984     0.003899     0.004153     0.003425
# 75%    6271.500000     0.006301     0.006076     0.005655     0.004242
# max    7831.000000     0.030600     0.036769     0.063814     0.077740
#
#             rrs555      chlor_a
# count  3255.000000  4127.000000
# mean      0.003256     2.680228
# std       0.003536     5.758436
# min       0.000183     0.012000
# 25%       0.001588     0.233325
# 50%       0.002071     0.764000
# 75%       0.003141     2.150000
# max       0.046600    77.864800

# %%
df_no_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 8 columns):
# id         4459 non-null int64
# rrs411     4293 non-null float64
# rrs443     4456 non-null float64
# rrs489     4422 non-null float64
# rrs510     3435 non-null float64
# rrs555     3255 non-null float64
# chlor_a    4127 non-null float64
# is_hplc    4459 non-null bool
# dtypes: bool(1), float64(6), int64(1)
# memory usage: 248.3 KB

# %% [markdown]
# ### $\Rightarrow$ Subset all columns leaving out rrs411 and rrs670 and dropping out any rows with at least one invalid entry

# %%
rrs_cols_nopurple_nored = rrs_cols[1:-1]

# %%
df_nopurple_nored = df.loc[:, ['id'] + rrs_cols_nopurple_nored + ['chlor_a', 'is_hplc']]

# %%
df_nopurple_nored.describe()
# Out:
#                 id       rrs443       rrs489       rrs510       rrs555  \
# count  4459.000000  4456.000000  4422.000000  3435.000000  3255.000000
# mean   4377.381251     0.004652     0.004590     0.004130     0.003256
# std    2298.272102     0.003002     0.002768     0.003130     0.003536
# min       6.000000     0.000190     0.000284     0.000261     0.000183
# 25%    2028.500000     0.002617     0.003051     0.002831     0.001588
# 50%    5039.000000     0.003899     0.004153     0.003425     0.002071
# 75%    6271.500000     0.006076     0.005655     0.004242     0.003141
# max    7831.000000     0.036769     0.063814     0.077740     0.046600
#
#            chlor_a
# count  4127.000000
# mean      2.680228
# std       5.758436
# min       0.012000
# 25%       0.233325
# 50%       0.764000
# 75%       2.150000
# max      77.864800

# %%
df_nopurple_nored.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 7 columns):
# id         4459 non-null int64
# rrs443     4456 non-null float64
# rrs489     4422 non-null float64
# rrs510     3435 non-null float64
# rrs555     3255 non-null float64
# chlor_a    4127 non-null float64
# is_hplc    4459 non-null bool
# dtypes: bool(1), float64(5), int64(1)
# memory usage: 213.4 KB

# %%
df_no_red.to_pickle('./pickleJar/df_clean_nored.pkl')
df_nopurple_nored.to_pickle('./pickleJar/df_clean_nopurple_nored.pkl')

# %% [markdown]
# ### End of this notebook on dataset cleanup & prep. Next: feature engineering for band ratio application.
